# %% [markdown]
# <a href="https://colab.research.google.com/github/ZeroLeon/fast_ai/blob/master/my_own_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fast_AI Learning(Lesson 1)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
folder = 'soup'
file = 'Chinese_soup.csv'

# %%
folder = 'chow_mein'
file = 'chow_mein.csv'

# %%
folder = 'udon'
file = 'udon.csv'

# %%
path = Path('/content/data/noodles')
dest = path/folder

# %%
# !cd /content/data/noodles

# %%
path_del = Path('/content/data/noodles/Chinese')

# %%
path_del.rmdir()

# %%
path.ls()
# Out:
# []

# %%
classes = ['soup','chow_mein','udon']

# %%
path = Path('/content/data/noodles')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file,dest,max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:15<00:00]
#     </div>
# Error https://my.openrice.com/userphoto/Article/0/Q/000565C5DCBC8C1F4BC393j.jpg ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))

# %%
for c in classes:
  print(c)
  verify_images(path/c,delete=True,max_size=500)
# Out:
# soup
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='99', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [99/99 00:03<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='/content/data/noodles/soup/00000051.jpg'>
# cannot identify image file <_io.BufferedReader name='/content/data/noodles/soup/00000033.jpg'>
# cannot identify image file <_io.BufferedReader name='/content/data/noodles/soup/00000030.jpg'>
# ...

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['chow_mein', 'soup', 'udon']

# %%
data.show_batch(row = 5,figsize=(7,8))
